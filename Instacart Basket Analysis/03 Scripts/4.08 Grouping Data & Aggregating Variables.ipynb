# %% [markdown]
# # 4.08 Task

# %% [markdown]
# ## Table of Contents
# 1. Import Libraries + Data
# 2. Grouping Data
# 3. Aggregating Data
#     - using agg()
#     - using transform()
# 4. Deriving Columns with loc()
# 5. Task 4.08
#     - find aggregated mean
#     - how do results differ?
#     - create a loyalty flag
#     - prices differ by loyalty?
#     - marketing to different spenders
#     - create order frequency flag
#     - export data

# %% [markdown]
# # 01. Import Libraries + Data

# %%
# Libraries
import pandas as pd
import numpy as np
import os

# %%
# path
path = r'/Users/alliecarlisle/Desktop/CareerFoundry_Data_Analytics/Instacart Basket Analysis'

# %%
# orders_products_merged_2
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_2.pkl'))

# %%
ords_prods_merge = ords_prods_merge.drop(columns=['busiest_day'])

# %%
# use subset of above dataframe
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
df.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2398795        1             2                       3                  7
# 1    473747        1             3                       3                 12
# 2   2254736        1             4                       4                  7
# 3    431534        1             5                       4                 15
# 4   3367565        1             6                       2                  7
# 5    550135        1             7                       1                  9
# 6   3108588        1             8                       1                 14
# 7   2295261        1             9                       1                 16
# 8   2550362        1            10                       4                  8
# 9   2968173       15            15                       1                  9
#
#    time_between_orders  product_id  add_to_cart_order  reordered product_name  \
# ...

# %% [markdown]
# # 02. Grouping Data

# %%
# split the data into the product_name group
df.groupby('product_name')

# %% [markdown]
# # 03. Aggregating Data

# %% [markdown]
# ### A. Using agg()

# %%
# split the data into groups based on department_id
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                19.765396
# 7                18.575283
# 13               18.950838
# 14               20.460336
# 16               20.262396
# 17               12.646785
# 19               20.168036
# 20               18.808671

# %%
# same as above but using the mean function instead
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     19.765396
# 7     18.575283
# 13    18.950838
# 14    20.460336
# 16    20.262396
# 17    12.646785
# 19    20.168036
# 20    18.808671
# Name: order_number, dtype: float64

# %%
# perform multiple aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                19.765396   2  99
# 7                18.575283   2  99
# 13               18.950838   2  99
# 14               20.460336   2  99
# 16               20.262396   2  99
# 17               12.646785   2  98
# 19               20.168036   2  99
# 20               18.808671   2  99

# %% [markdown]
# ### B. Using transform()

# %%
# split the data into groups based on user_id, transform to generate max, and create max_order column
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_the_week  \
# 0    2398795        1             2                       3
# 1     473747        1             3                       3
# 2    2254736        1             4                       4
# 3     431534        1             5                       4
# 4    3367565        1             6                       2
# 5     550135        1             7                       1
# 6    3108588        1             8                       1
# 7    2295261        1             9                       1
# 8    2550362        1            10                       4
# 9    2968173       15            15                       1
# 10   1870022       15            17                       2
# 11   1911383       15            18                       2
# 12   2715276       15            21                       1
# 13    487368       15            22                       1
# 14   2293453       19             2                       5
#
# ...

# %% [markdown]
# ### use these to display all 100 rows - - > pd.options.display.max_rows = None - - > ords_prods_merge.head(100)

# %% [markdown]
# # 04. Deriving Columns with loc()

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15081691
# Loyal customer      10095381
# New customer         5151691
# Name: loyalty_flag, dtype: int64

# %%
# check
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             2
# 1         1      New customer             3
# 2         1      New customer             4
# 3         1      New customer             5
# 4         1      New customer             6
# 5         1      New customer             7
# 6         1      New customer             8
# 7         1      New customer             9
# 8         1      New customer            10
# 9        15  Regular customer            15
# 10       15  Regular customer            17
# 11       15  Regular customer            18
# 12       15  Regular customer            21
# 13       15  Regular customer            22
# 14       19      New customer             2
# 15       19      New customer             5
# 16       19      New customer             7
# 17       21  Regular customer            10
# 18       31  Regular customer            10
# 19       31  Regular customer            17
# ...

# %% [markdown]
# # 05. 4.08 Task

# %% [markdown]
# ### 02. Find the aggregated mean of entire dataframe

# %%
# split the data into groups based on department_id
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                16.559358
# 2                18.413176
# 3                18.279600
# 4                18.915890
# 5                16.497751
# 6                17.609390
# 7                18.303975
# 8                16.383301
# 9                17.022963
# 10               21.227447
# 11               17.311768
# 12               16.953613
# 13               17.727470
# 14               17.898097
# 15               17.290123
# 16               18.757796
# 17               16.808683
# 18               20.336389
# 19               18.258620
# 20               17.578959
# 21               23.644477

# %% [markdown]
# ### 03. How do the results for entire dataframe differ from subset? Answer - With the subset, we only received a select number of departments - here we have every single department which is more useful for performing an analysis.

# %% [markdown]
# ### 04. Create a loyalty flag for existing customers - see above sections 03, A and 04

# %% [markdown]
# ### 05. Do prices differ by loyalty?

# %%
# Group by prices 
ords_prods_merge.groupby('prices')

# %%
# split the data into groups based on loyalty_flag
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.402162  1.0  99999.0
# New customer      13.396333  1.0  99999.0
# Regular customer  12.546842  1.0  99999.0

# %% [markdown]
# ### 06. Marketing to different spenders

# %%
# create new column - mean_price
ords_prods_merge['mean_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_the_week  \
# 0    2398795        1             2                       3
# 1     473747        1             3                       3
# 2    2254736        1             4                       4
# 3     431534        1             5                       4
# 4    3367565        1             6                       2
# ..       ...      ...           ...                     ...
# 95   1548901      546             4                       3
# 96    668870      591             2                       1
# 97   2483801      626             2                       5
# 98   2741904      626             6                       1
# 99   2138689      626            10                       1
#
#     order_hour_of_day  time_between_orders  product_id  add_to_cart_order  \
# 0                   7                 15.0         196                  1
# 1                  12                 21.0         196                  1
# ...

# %%
# create spending flag
ords_prods_merge.loc[ords_prods_merge['mean_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
# create spending flag
ords_prods_merge.loc[ords_prods_merge['mean_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
# check
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     29730505
# High spender      598258
# Name: spending_flag, dtype: int64

# %% [markdown]
# ### 07. Create an order frequency flag

# %%
# create median days column
ords_prods_merge['median_days'] = ords_prods_merge.groupby(['user_id'])['time_between_orders'].transform(np.median)

# %%
# check
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_the_week  \
# 0    2398795        1             2                       3
# 1     473747        1             3                       3
# 2    2254736        1             4                       4
# 3     431534        1             5                       4
# 4    3367565        1             6                       2
# ..       ...      ...           ...                     ...
# 95   1548901      546             4                       3
# 96    668870      591             2                       1
# 97   2483801      626             2                       5
# 98   2741904      626             6                       1
# 99   2138689      626            10                       1
#
#     order_hour_of_day  time_between_orders  product_id  add_to_cart_order  \
# 0                   7                 15.0         196                  1
# 1                  12                 21.0         196                  1
# ...

# %%
# create frequency flag
ords_prods_merge.loc[ords_prods_merge['median_days'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days'] > 10) & (ords_prods_merge['median_days'] <= 20), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# check
ords_prods_merge['frequency_flag'].value_counts(dropna=False)
# Out:
# Frequent customer        20675290
# Regular customer          6594542
# Non-frequent customer     3058931
# Name: frequency_flag, dtype: int64

# %% [markdown]
# ### 08. Export dataframe

# %%
# export to pickle file
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_aggregated.pkl'))
